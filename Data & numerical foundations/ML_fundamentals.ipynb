# %%
import numpy as np


def gradient_descent():
    
    w = 10
    learning_rate = 0.1
    
    for i in range(20):
        gradient = 2 * w
        w = w - (learning_rate * gradient)
        
        print(f"Epoch: {i+1}, New: {w:.3f} ")
        
gradient_descent()
# Out:
# Epoch 0: Loss=44.0000, w=0.4400, b=0.1200
# Epoch 100: Loss=0.0245, w=1.8988, b=0.3655
# Epoch 200: Loss=0.0124, w=1.9279, b=0.2605
# Epoch 300: Loss=0.0063, w=1.9486, b=0.1856
# Epoch 400: Loss=0.0032, w=1.9634, b=0.1323
# Epoch 500: Loss=0.0016, w=1.9739, b=0.0943
# Epoch 600: Loss=0.0008, w=1.9814, b=0.0672
# Epoch 700: Loss=0.0004, w=1.9867, b=0.0479
# Epoch 800: Loss=0.0002, w=1.9905, b=0.0341
# Epoch 900: Loss=0.0001, w=1.9933, b=0.0243
#
# Final parameters:
# w = 1.9951803506719779
# b = 0.017400463340610635

# %%
import numpy as np

# Linear regretion from scratch
# Training dataset

X = np.array([1,2,3,4,5], dtype=float) # samples
Y = np.array([2,4,6,8,10], dtype=float) # Labels

# Initial parameters

w = 0.0
b= 0.0

learning_rate = 0.01
epochs = 1000

for epoch in range(epochs):
    # Find initial prediction
    y_pred = w * X + b
    
    # Find loss
    loss = np.mean((Y - y_pred)**2)
    
    # Find gradients
    dw = np.mean((-2*X) * (Y - y_pred))
    db = np.mean(-2 * (Y - y_pred))
    
    # Update parameters
    
    w = w - learning_rate * dw
    b = b - learning_rate * db
    
    if epoch % 100 == 0:
        print(f"Epoch: {epoch:03}  w: {w:.3f}  b: {b:.3f}  Loss: {loss:.3f}")
# Out:
# Epoch: 000  w: 0.440  b: 0.120  Loss: 44.000
# Epoch: 100  w: 1.899  b: 0.365  Loss: 0.024
# Epoch: 200  w: 1.928  b: 0.260  Loss: 0.012
# Epoch: 300  w: 1.949  b: 0.186  Loss: 0.006
# Epoch: 400  w: 1.963  b: 0.132  Loss: 0.003
# Epoch: 500  w: 1.974  b: 0.094  Loss: 0.002
# Epoch: 600  w: 1.981  b: 0.067  Loss: 0.001
# Epoch: 700  w: 1.987  b: 0.048  Loss: 0.000
# Epoch: 800  w: 1.991  b: 0.034  Loss: 0.000
# Epoch: 900  w: 1.993  b: 0.024  Loss: 0.000

# %%
import pandas as pd

data = {
    "age": [18, 19, 20, 21, 22, 23, 24],
    "study_hours": [2, 4, 5, 6, 7, 8, 9],
    "attendance": [70, 80, 82, 88, 90, 95, 97],
    "passed": [0, 0, 1, 1, 1, 1, 1]
}

passed = pd.DataFrame(data)
passed.head()
df.info()
df.describe()
df.isnull().sum()
df.duplicated().sum() # For Duplicated rows

import matplotlib.pyplot as plt
import seaborn as sys

sys.histplot(df["study_hours"])
sys.boxplot(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          7 non-null      int64
#  1   study_hours  7 non-null      int64
#  2   attendance   7 non-null      int64
#  3   passed       7 non-null      int64
# dtypes: int64(4)
# memory usage: 356.0 bytes
# <Axes: xlabel='study_hours', ylabel='Count'>
