# %%
import numpy as np

array = np.array([1,2,3,4,5,6,7,8])

matrix = np.array([
    [1,2,3,4],[5,6,7,8]
])

matrix.ndim
matrix.size
matrix.shape
array.shape
array.reshape(2,4)
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])
